# %%
import pandas as pd
pd.set_option('display.min_rows', 20)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('league_pick_details.csv')

# %%
df = df.drop([
    'is_captain',
    'is_vice_captain',
    'multiplier',
    
], axis=1)

# %% [markdown]
# 1. Most Improved from Christmas
#     - Person with the largest percentage of their score where gw ≥ 20

# %% [markdown]
# total_points = points for the week

# %% [markdown]
# total_points

# %%
df
# Out:
#      ...      ...           ...             ...        ...              ...               ...           ...        ...    ...    ...  ...        ...         ...     ...        ...           ...           ...   ...            ...          ...        ...                 ...               ...                   ...                 ...              ...              ...            ...              ...                     ...                    ...              ...          ...           ...                 ...                          ...                           ...                           ...     ...         ...              ...      ...      ...           ...               ...   ...                 ...                                                ...                          ...          ...           ...              ...                       ...           ...    ...                 ...
# ...

# %%
# First get the total scores
df.groupby(['game_week']).count().reset_index()#[['entry_name']]
# Out:
# 135           135             135        135              135               135           135        135    135    135  135        135         135     135        135           135           135   135            135          135        135                 135               135                   135                 135              135              135            135              135                     135                    135              135          135           135                 135    135                           113                           112   135         135              135        0        0           135         135   135                 135     1         113            0             0              135          135             0     135                 135       135             135                  135              135                   135          135               135
# ...

# %%
# First get the total scores
df.groupby(['entry_name']).sum('total_points').reset_index()[['entry_name', 'total_points']].sort_values(['total_points'])
# Out:
#             entry_name  total_points
# 6  Matip of my Willian          1806
# 5         Inter Yernan          1830
# 7     McGinn and Tonic          1831
# 0       Bilbao Baggins          1836
# 1      Boom Xhaka Laka          1842
# 2       Bottoms "R" Us          1881
# 3  Capoue on your shoe          1886
# 4     Dyche Dyche Baby          1887
# 8             Pepe Pig          1933

# %%
# First get the total scores
df.groupby(['entry_name']).sum('total_points').reset_index()[['entry_name', 'total_points']]

# %%
game_weeks_over_20 = df[df['game_week'] >= 20]
game_weeks_over_20
# Out:
#     1            3                 2               3                    1             4    17           4             92       Forward                 FWD     Forwards               FWD    174070     Dyche Dyche Baby  174474  2020-09-02T14:45:13.292727Z           Dominic             Rech         DR          NaN         38
# 5081               7                    3              423                     9          682                69             134                    4             1    10           1             80    Goalkeeper                 GKP  Goalkeepers               GKP    174070     Dyche Dyche Baby  174474  2020-09-02T14:45:13.292727Z           Dominic             Rech         DR          NaN         38
# ...

# %% [markdown]
# 2. Scores from Draft Picks VS End Scores
#     - BONUS - Scores for each week's picks VS End Scores

# %%
df
# Out:
#       element  position  is_captain  is_vice_captain  multiplier  minutes  \
# 0         363         1       False            False           1       90
# 1         259         2       False            False           1       88
# 2         471         3       False            False           1        0
# 3         492         4       False            False           1       90
# 4         354         5       False            False           1       90
# ...       ...       ...         ...              ...         ...      ...
# 5125       91        11       False            False           1       90
# 5126      217        12       False            False           1       90
# 5127       88        13       False            False           1        0
# 5128      313        14       False            False           1        0
# 5129      340        15       False            False           1        0
#
#       goals_scored  assists  clean_sheets  goals_conceded  ...  \
# ...

# %% [markdown]
# 3. Points missed from the bench
#     - Total
#     - Largest GW

# %% [markdown]
# 4. Top Percentage of total points for each player

# %% [markdown]
# 5. Biggest Drop
